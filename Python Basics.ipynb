# %% [markdown]
# # Python Basic Questions
# ### 1. what is python and why it is popular?
# Answer- Python is a high-level, general-purpose programming language known for being easy to read, easy to learn, and very versatile.
#
# ### 2. What is an interpreter in Python?
# Answer- In Python, an interpreter is the program that reads and executes your Python code line by line.
#
# ### 3. What are pre-defined keywords in Python?
# Answer- Pre-defined keywords in Python are special reserved words that have fixed meanings in the language. You cannot use them as variable names, function names, or identifiers because Python uses them for its own syntax and structure.
#
# ### 4.  Can keywords be used as variable names?
# Answer- No, keywords cannot be used as variable names in Python.
#
# ### 5. What is mutability in Python?
# Answer- Mutability in Python refers to whether an object’s value can be changed after it is created.
#
# ### 6. Why are lists mutable, but tuples are immutable?
# Answer- Lists are mutable and tuples are immutable because they are designed for different purposes and implemented differently in Python’s memory model.
#
# ### 7. What is the difference between “==” and “is” operators in Pytho?
# Answer- In Python, == and is are both comparison operators, but they check different things.
# == → Are the values the same?
#
# is → Are they the same object?
#
# ### 8.  What are logical operators in Python?
# Answer- In Python, logical operators are used to combine or compare Boolean values (True or False). They help control the flow of decisions in a program.
#
# ### 9. What is type casting in Python?
# Answer- Type casting in Python means converting one data type into another.
#
# ### 10.  What is the difference between implicit and explicit type casting?
# Answer- Implicit → Python quietly converts for you.
#
# Explicit → You tell Python exactly how to convert.
#
# ### 11.  What is the purpose of conditional statements in Python?
# Answer- Conditional statements in Python are used to make decisions in a program based on certain conditions.
#
# ### 12.  How does the elif statement work?
# Answer- The elif statement in Python stands for “else if”. It allows you to check multiple conditions in sequence after an initial if statement. It only executes the block of the first condition that is True and skips the rest.
#
# ### 13.  What is the difference between for and while loops?
# Answer- The difference between for loops and while loops mainly comes down to how and when the looping condition is checked and what they are typically used for.
#
# ### 14.  Describe a scenario where a while loop is more suitable than a for loop.
# Answer- Scenario: Asking a user for a correct password
#
# Imagine you’re writing a program that asks a user to enter a password. You don’t know in advance how many attempts it will take for them to enter it correctly. You want to keep prompting them until they get it right.

# %%
correct_password = "open123"
user_input = ""

while user_input != correct_password:
    user_input = input("Enter your password: ")

print("Access granted!")

# %% [markdown]
# # Practical Questions

# %% [markdown]
# ### 1.  Write a Python program to print "Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### 2.  Write a Python program that displays your name and age.

# %%
name= "Subhanjali" 
age= "20"
print("My name is", name)
print("I am", age, "years old")
# Out:
# My name is Subhanjali
# I am 20 years old

# %% [markdown]
# ### 3. Write code to print all the pre-defined keywords in Python using the keyword library.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 4. Write a program that checks if a given word is a Python keyword.

# %%
# Program to check if a given word is a Python keyword
import keyword

# Ask the user to enter a word
word = input("Enter a word to check if it is a Python keyword: ")

# Check if the word is a keyword
if keyword.iskeyword(word):
    print(f'"{word}" is a Python keyword.')
else:
    print(f'"{word}" is NOT a Python keyword.')

# %% [markdown]
# ### 5.  Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.

# %%
# Creating a list and a tuple
my_list = [10, 20, 30]
my_tuple = (10, 20, 30)

print("Original list:", my_list)
print("Original tuple:", my_tuple)

# Changing an element in the list
my_list[1] = 99
print("Updated list:", my_list)

# Attempting to change an element in the tuple
try:
    my_tuple[1] = 99
except TypeError as e:
    print("Error while updating tuple:", e)

# %% [markdown]
# ### 6.  Write a function to demonstrate the behavior of mutable and immutable arguments.

# %%
# Function to modify a mutable and an immutable argument
def modify_data(num, my_list):
    # Attempt to change immutable argument (int)
    num += 10
    # Modify mutable argument (list)
    my_list.append(100)
    print("Inside function - num:", num)
    print("Inside function - my_list:", my_list)

# Immutable argument
x = 5
# Mutable argument
lst = [1, 2, 3]

print("Before function call - x:", x)
print("Before function call - lst:", lst)

modify_data(x, lst)

print("After function call - x:", x)      # x is unchanged
print("After function call - lst:", lst)  # lst is changed

# %% [markdown]
# ### 7. Write a program that performs basic arithmetic operations on two user-input numbers.

# %%
# Program to perform basic arithmetic operations

# Take input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Perform arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2

# Handle division carefully to avoid division by zero
if num2 != 0:
    division = num1 / num2
else:
    division = "Undefined (division by zero)"

# Display results
print(f"{num1} + {num2} = {addition}")
print(f"{num1} - {num2} = {subtraction}")
print(f"{num1} * {num2} = {multiplication}")
print(f"{num1} / {num2} = {division}")

# %% [markdown]
# ### 8.  Write a program to demonstrate the use of logical operators

# %%
# Program to demonstrate logical operators

# Take two boolean inputs from the user
x = input("Enter True or False for x: ").strip().capitalize() == "True"
y = input("Enter True or False for y: ").strip().capitalize() == "True"

# Using logical AND
print(f"x AND y: {x and y}")

# Using logical OR
print(f"x OR y: {x or y}")

# Using logical NOT
print(f"NOT x: {not x}")
print(f"NOT y: {not y}")

# %% [markdown]
# ### 9. Write a Python program to convert user input from string to integer, float, and boolean types.

# %%
# Program to convert user input into different data types

# Take input from the user (input is always a string)
user_input = input("Enter something: ")

# Convert to integer
try:
    int_value = int(user_input)
except ValueError:
    int_value = "Cannot convert to integer"

# Convert to float
try:
    float_value = float(user_input)
except ValueError:
    float_value = "Cannot convert to float"

# Convert to boolean
# In Python, any non-empty string is considered True
bool_value = bool(user_input.strip())

# Display results
print(f"Original input (string): '{user_input}'")
print(f"Integer conversion: {int_value}")
print(f"Float conversion: {float_value}")
print(f"Boolean conversion: {bool_value}")

# %% [markdown]
# ### 10. Write code to demonstrate type casting with list elements.

# %%
# Original list with string numbers
str_list = ["10", "20", "30", "40"]

print("Original list (strings):", str_list)

# Convert each element from string to integer
int_list = [int(item) for item in str_list]
print("List after casting to integers:", int_list)

# Convert each element from integer to float
float_list = [float(item) for item in int_list]
print("List after casting to floats:", float_list)

# Convert each element from float back to string
str_list_again = [str(item) for item in float_list]
print("List after casting back to strings:", str_list_again)

# %% [markdown]
# ### 11.  Write a program that checks if a number is positive, negative, or zero.

# %%
# Program to check if a number is positive, negative, or zero

# Take input from the user
num = float(input("Enter a number: "))

# Check the number
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# %% [markdown]
# ### 12.  Write a for loop to print numbers from 1 to 10.

# %%
# Program to print numbers from 1 to 10 using a for loop

for i in range(1, 11):
    print(i)

# %% [markdown]
# ### 13. Write a Python program to find the sum of all even numbers between 1 and 50.

# %%
# Program to find the sum of all even numbers from 1 to 50

# Initialize sum
even_sum = 0

# Loop through numbers from 1 to 50
for num in range(1, 51):
    if num % 2 == 0:   # Check if the number is even
        even_sum += num

print("The sum of all even numbers from 1 to 50 is:", even_sum)

# %% [markdown]
# ### 14. Write a program to reverse a string using a while loop.

# %%
str1= 'Data Science'
str1[::-1]
# Out:
# 'ecneicS ataD'

# %% [markdown]
# ### 15.  Write a Python program to calculate the factorial of a number provided by the user using a while loop.

# %%
# Program to calculate factorial using a while loop

# Take input from the user
num = int(input("Enter a non-negative integer: "))

# Initialize factorial result
factorial = 1
i = 1

# Check if the number is non-negative
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    # Calculate factorial using while loop
    while i <= num:
        factorial *= i
        i += 1

    print(f"The factorial of {num} is: {factorial}")
